# %%
#import library packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
data=pd.read_csv('Data.csv')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#    Unnamed: 0                             address  year  day  length  \
# 0           0  112Ns49UobQn1cX1G1axs1cmGvjFBxVxvf  2016  146     144
# 1           1  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  158      56
# 2           2  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  156       8
# 3           3  113ESVqntvYprqQbsPN6tEmtE1bB44uokS  2016  155       6
# 4           4  114gGmini5G9hEwEkWtKXoQqT1D6S5AJvU  2016  137       0
#
#      weight  count  looped  neighbors       income             label
# 0  0.877485   4817       0          1  104020000.0  montrealCryptXXX
# 1  0.000031      1       0          1  120000000.0  montrealCryptXXX
# 2  0.750000      2       0          4  240000000.0  montrealCryptXXX
# 3  0.500000      6       0          2  120000000.0  montrealCryptXXX
# 4  1.000000      1       0          2  119990000.0  montrealCryptXXX

# %%
data.shape
# Out:
# (14514, 11)

# %%
del data['Unnamed: 0']
del data['address']

# %%
data.head()
# Out:
#    year  day  length    weight  count  looped  neighbors       income  \
# 0  2016  146     144  0.877485   4817       0          1  104020000.0
# 1  2016  158      56  0.000031      1       0          1  120000000.0
# 2  2016  156       8  0.750000      2       0          4  240000000.0
# 3  2016  155       6  0.500000      6       0          2  120000000.0
# 4  2016  137       0  1.000000      1       0          2  119990000.0
#
#               label
# 0  montrealCryptXXX
# 1  montrealCryptXXX
# 2  montrealCryptXXX
# 3  montrealCryptXXX
# 4  montrealCryptXXX

# %%
data['label']=data['label'].map({'montrealCryptXXX':'Crypt','montrealCryptoLocker':'CryptoLocker','paduaCryptoWall':'CryptoWall','princetonCerber':'Cerber','princetonLocky':'Locky','white':'White'})

# %%
data.head()
# Out:
#    year  day  length    weight  count  looped  neighbors       income  label
# 0  2016  146     144  0.877485   4817       0          1  104020000.0  Crypt
# 1  2016  158      56  0.000031      1       0          1  120000000.0  Crypt
# 2  2016  156       8  0.750000      2       0          4  240000000.0  Crypt
# 3  2016  155       6  0.500000      6       0          2  120000000.0  Crypt
# 4  2016  137       0  1.000000      1       0          2  119990000.0  Crypt

# %%
data["label"].value_counts()
# Out:
# Crypt           2419
# CryptoLocker    2419
# CryptoWall      2419
# Cerber          2419
# Locky           2419
# White           2419
# Name: label, dtype: int64

# %%
data.shape
# Out:
# (14514, 9)

# %%
#Histogram for histogram_max & histogram_min
data['count'].hist(figsize=(5,5), color='black', alpha=1)
plt.xlabel('count')
plt.ylabel('value')
plt.title('count')
# Out:
# Text(0.5, 1.0, 'count')

# %%
plt.figure(figsize=(16,4))

plt.scatter(data['looped'],data['label'])
plt.xlabel("looped")
plt.ylabel("label")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,10))
s.heatmap(data.corr(),annot = True, fmt='0.2%',cmap = 'Reds',ax=ax)
# Out:
# <AxesSubplot:>

# %%
s.boxplot(data['day'])
plt.show()

# %%
data.columns
# Out:
# Index(['year', 'day', 'length', 'weight', 'count', 'looped', 'neighbors',
#        'income', 'label'],
#       dtype='object')

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(data, 'label')
# Out:
# CryptoWall      16.67
# Locky           16.67
# Cerber          16.67
# CryptoLocker    16.67
# Crypt           16.67
# White           16.67
# Name: label, dtype: float64

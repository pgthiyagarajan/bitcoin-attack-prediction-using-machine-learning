# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Data.csv')

# %%
data
# Out:
#        Unnamed: 0                             address  year  day  length  \
# 0               0  112Ns49UobQn1cX1G1axs1cmGvjFBxVxvf  2016  146     144
# 1               1  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  158      56
# 2               2  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  156       8
# 3               3  113ESVqntvYprqQbsPN6tEmtE1bB44uokS  2016  155       6
# 4               4  114gGmini5G9hEwEkWtKXoQqT1D6S5AJvU  2016  137       0
# ...           ...                                 ...   ...  ...     ...
# 14509       14509  1MgznHE8cHx7rHhywkkGNzjTSKefrZ2Jtk  2013  159       4
# 14510       14510  19HvxWiz8RFQ9hrR4t5TQRiKrpDB9mC2Pr  2014    3       0
# 14511       14511  1HwF24L61LLg81jLvq7KCnkFudYHNXNx83  2011  309       8
# 14512       14512  12qgrq2xgE7VukMcAHh3Nwksf9a43AoCaa  2014  169      12
# 14513       14513  17CGnX5Dyc3mpBmSMrzSqYMnmqb4v9fM7p  2018  304      30
#
#          weight  count  looped  neighbors        income             label
# ...

# %%
data.shape
# Out:
# (14514, 11)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'address', 'year', 'day', 'length', 'weight', 'count',
#        'looped', 'neighbors', 'income', 'label'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14514 entries, 0 to 14513
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14514 non-null  int64
#  1   address     14514 non-null  object
#  2   year        14514 non-null  int64
#  3   day         14514 non-null  int64
#  4   length      14514 non-null  int64
#  5   weight      14514 non-null  float64
#  6   count       14514 non-null  int64
#  7   looped      14514 non-null  int64
#  8   neighbors   14514 non-null  int64
#  9   income      14514 non-null  float64
#  10  label       14514 non-null  object
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0          year           day        length        weight  \
# count  14514.000000  14514.000000  14514.000000  14514.000000  1.451400e+04
# mean    7256.500000   2015.010197    174.846562     43.034587  5.492787e-01
# std     4189.975239      1.554373     91.263246     58.536232  1.578841e+00
# min        0.000000   2011.000000      1.000000      0.000000  1.177281e-72
# 25%     3628.250000   2014.000000     97.000000      2.000000  3.639131e-02
# 50%     7256.500000   2016.000000    161.000000      8.000000  2.722658e-01
# 75%    10884.750000   2016.000000    250.000000     88.000000  8.319469e-01
# max    14513.000000   2018.000000    365.000000    144.000000  1.477504e+02
#
#               count        looped     neighbors        income
# count  14514.000000  14514.000000  14514.000000  1.451400e+04
# mean     670.591429    115.048712      2.071104  1.020469e+09
# std     1551.611539    644.582290      5.138103  1.343035e+10
# ...

# %%
# duplicated values
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14509    False
# 14510    False
# 14511    False
# 14512    False
# 14513    False
# Length: 14514, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.year.unique()
# Out:
# array([2016, 2013, 2012, 2014, 2011, 2015, 2017, 2018], dtype=int64)

# %%
data.length.unique()
# Out:
# array([144,  56,   8,   6,   0,   2,   4,  36,  44, 122,  74,  28,  12,
#         46,  50,  26, 108,  32,  18,  10,  14,  72,  16,  42,  20,  58,
#         34,  66,  64,  24,  40, 102, 100,  94,  78,  30,  86,  52,  88,
#         38,  82, 124, 142, 106,  90, 138,  70,  22, 140,  60, 110,  62,
#         48,  68,  76,  54,  98,  84, 116,  92, 120, 132,  80,  96, 112,
#        104, 114, 118, 128, 126, 134, 136, 130], dtype=int64)

# %%
data.looped.unique()
# Out:
# array([    0,    10,  2973,  1702,  1280,     4,     1,   180,  2617,
#         1199,     5,  1732,     2,  3373,  2411,  3159,   886,  1379,
#            3,  1626,  2606,  1223,  2733,   421,    13,    15,  1348,
#         8489,    22,     6,   607,  2156,  1508,  4775,   198,   405,
#         1526,  2331,  8350,  2238,  3825,   161,  6247,  3656,  7851,
#         1787,  3818,  1825,   943,     9,  1680,  2493,  2544,   832,
#           23,  1882,  5715,   642,  1618,   990,  1054,  1538,   216,
#         5033,     7,  3837,  3609,  1344,   509,     8,    49,  1978,
#         2093,    24,  1354,  1993,  1186,   981,  1988,   567,   631,
#         3378,    29,  5754,   595,   423,  4326,  3752,  1419,  2744,
#         1087,    14,  2494,    96,  5838,  2058,  1305,  3658,    18,
#         2435,  3497,    20,  2774,   762,  4558,  5624,    79,  2581,
#         3194,    27,  6195,    21,  1518,    76,   865,  4557,  1859,
# ...

# %%
data.neighbors.unique()
# Out:
# array([  1,   4,   2,   6,   5,   3,   9,   8,  12,  11,  10,  13,  15,
#          7,  14,  23,  17,  19,  18,  21,  27,  24,  38,  16,  28,  20,
#         49,  33,  36,  69,  44,  34,  22,  31,  58,  45,  30,  41,  26,
#        514, 122,  32, 205], dtype=int64)

# %%
data.label.unique()
# Out:
# array(['montrealCryptXXX', 'montrealCryptoLocker', 'paduaCryptoWall',
#        'princetonCerber', 'princetonLocky', 'white'], dtype=object)

# %%
print("Minimum Value of Weight is : ",data.weight.min())
print("Maximum Value of Weight is : ",data.weight.max())
# Out:
# Minimum Value of Weight is :  1.1772812437066795e-72
# Maximum Value of Weight is :  147.750413309429

# %%
data.head()
# Out:
#    Unnamed: 0                             address  year  day  length  \
# 0           0  112Ns49UobQn1cX1G1axs1cmGvjFBxVxvf  2016  146     144
# 1           1  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  158      56
# 2           2  112wED5uHhY1aiSaWAzgeMDaCKFcCvj9Pn  2016  156       8
# 3           3  113ESVqntvYprqQbsPN6tEmtE1bB44uokS  2016  155       6
# 4           4  114gGmini5G9hEwEkWtKXoQqT1D6S5AJvU  2016  137       0
#
#      weight  count  looped  neighbors       income             label
# 0  0.877485   4817       0          1  104020000.0  montrealCryptXXX
# 1  0.000031      1       0          1  120000000.0  montrealCryptXXX
# 2  0.750000      2       0          4  240000000.0  montrealCryptXXX
# 3  0.500000      6       0          2  120000000.0  montrealCryptXXX
# 4  1.000000      1       0          2  119990000.0  montrealCryptXXX

# %%
pd.Categorical(data["year"]).describe()
# Out:
#             counts     freqs
# categories
# 2011           318  0.021910
# 2012           499  0.034381
# 2013          2299  0.158399
# 2014          2343  0.161430
# 2015           947  0.065247
# 2016          6653  0.458385
# 2017          1160  0.079923
# 2018           295  0.020325

# %%
data.corr()
# Out:
#             Unnamed: 0      year       day    length    weight     count  \
# Unnamed: 0    1.000000  0.097252 -0.114927  0.027510 -0.032299  0.065706
# year          0.097252  1.000000 -0.247741  0.085817 -0.102635  0.185042
# day          -0.114927 -0.247741  1.000000 -0.023085  0.023450 -0.029192
# length        0.027510  0.085817 -0.023085  1.000000  0.024781  0.739645
# weight       -0.032299 -0.102635  0.023450  0.024781  1.000000  0.027671
# count         0.065706  0.185042 -0.029192  0.739645  0.027671  1.000000
# looped        0.060980  0.015661 -0.005646  0.306570  0.141351  0.443543
# neighbors    -0.035672 -0.066005  0.029010  0.065323  0.791303  0.031695
# income        0.033669 -0.088111  0.013490  0.009647  0.083804 -0.005522
#
#               looped  neighbors    income
# Unnamed: 0  0.060980  -0.035672  0.033669
# year        0.015661  -0.066005 -0.088111
# day        -0.005646   0.029010  0.013490
# length      0.306570   0.065323  0.009647
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'address', 'year', 'day', 'length', 'weight', 'count',
#        'looped', 'neighbors', 'income', 'label'],
#       dtype='object')

# %%
a =data.label.unique()

# %%
data.label.unique()
# Out:
# array(['montrealCryptXXX', 'montrealCryptoLocker', 'paduaCryptoWall',
#        'princetonCerber', 'princetonLocky', 'white'], dtype=object)

# %%
del data['address']

# %%
data['label']=data['label'].map({'montrealCryptXXX':'MontrealCrypt','montrealCryptoLocker':'MontrealCryptoLocker','paduaCryptoWall':'PaduaCryptoWall','princetonCerber':'PrincetonCerber','princetonLocky':'PrincetonLocky','white':'White'})

# %%
data.head()
# Out:
#    Unnamed: 0  year  day  length    weight  count  looped  neighbors  \
# 0           0  2016  146     144  0.877485   4817       0          1
# 1           1  2016  158      56  0.000031      1       0          1
# 2           2  2016  156       8  0.750000      2       0          4
# 3           3  2016  155       6  0.500000      6       0          2
# 4           4  2016  137       0  1.000000      1       0          2
#
#         income          label
# 0  104020000.0  MontrealCrypt
# 1  120000000.0  MontrealCrypt
# 2  240000000.0  MontrealCrypt
# 3  120000000.0  MontrealCrypt
# 4  119990000.0  MontrealCrypt

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
var_mod = ['label']

for i in var_mod:
    data[i] = le.fit_transform(data[i].astype(str))

# %%
data.head()
# Out:
#    Unnamed: 0  year  day  length    weight  count  looped  neighbors  \
# 0           0  2016  146     144  0.877485   4817       0          1
# 1           1  2016  158      56  0.000031      1       0          1
# 2           2  2016  156       8  0.750000      2       0          4
# 3           3  2016  155       6  0.500000      6       0          2
# 4           4  2016  137       0  1.000000      1       0          2
#
#         income  label
# 0  104020000.0      0
# 1  120000000.0      0
# 2  240000000.0      0
# 3  120000000.0      0
# 4  119990000.0      0
